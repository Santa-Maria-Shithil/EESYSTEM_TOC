# %%
import matplotlib.pyplot as plt
import numpy as np

#throughput at different conflict 15 client

i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]


tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)




a=[]

#a.append(0.0)

b=[]

#b.append(0.0)

c=[]

#c.append(0.0)


d=[]

j=0
myfile = open("updated_rps\ol_tput_10_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y1.append(float(line))
            x1.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open("updated_rps\ol_tput_20_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y2.append(float(line))
            x2.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 



j=0
myfile = open("updated_rps\ol_tput_25_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y3.append(float(line))
            x3.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 


j=0
myfile = open("updated_rps\ol_tput_30_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y4.append(float(line))
            x4.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()


j=0
myfile = open("updated_rps\ol_tput_35_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y5.append(float(line))
            x5.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()

plt.ylim(0,50000)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)



plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='10 clients (serviced all request)') 
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='20 clients (serviced all request)')
plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='25 clients (serviced all request)')
plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='30 clients (serviced all request)')
plt.plot(x5, y5, color='orange', linestyle='solid', linewidth = 1, label='35 clients (serviced 3/4th of all request)')


plt.xlabel('Time (s)')
# naming the y axis
plt.ylabel('Throughput (ops/s)')
plt.annotate('conflict=25%', xy = (0.6, 0.9), xycoords='axes fraction')
plt.annotate('rps=600', xy = (0.6, 0.8), xycoords='axes fraction')

#plt.title('Throughput with Different Amount of Load', y=-0.9)

  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.9));
# function to show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

 
#aggregate cpu usage of the individual process at different conflict. 15 Clients  
    
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]

tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)


path="E:\\git repository\\copilot\\scripts\\updated_rps\\"

j=0
myfile = open(path+"ol_agg_cpu_usage_median_10_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y1.append(float(line))
            x1.append(j)
            j=j+1
            y1.append(float(line))
            x1.append(j)
            j=j+1
            y1.append(float(line))
            x1.append(j)
            j=j+1
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 



j=0
myfile = open(path+"ol_agg_cpu_usage_median_20_clients.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            y2.append(float(line))
            x2.append(j)
            j=j+1
            y2.append(float(line))
            x2.append(j)
            j=j+1
            y2.append(float(line))
            x2.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  

     
        
j=0
myfile = open(path+"ol_agg_cpu_usage_median_25_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y3.append(float(line))
            x3.append(j)
            j=j+1
            y3.append(float(line))
            x3.append(j)
            j=j+1
            y3.append(float(line))
            x3.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  
 
j=0
myfile = open(path+"ol_agg_cpu_usage_median_30_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y4.append(float(line))
            x4.append(j)
            j=j+1
            y4.append(float(line))
            x4.append(j)
            j=j+1
            y4.append(float(line))
            x4.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 



j=0
myfile = open(path+"ol_agg_cpu_usage_median_35_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y5.append(float(line))
            x5.append(j)
            j=j+1
            y5.append(float(line))
            x5.append(j)
            j=j+1
            y5.append(float(line))
            x5.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 

  


plt.ylim(0,1500)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)



plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='10 clients (serviced all request)') 
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='20 clients (serviced all request)')
plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='25 clients (serviced all request)')
plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='30 clients (serviced all request)')
plt.plot(x5, y5, color='orange', linestyle='solid', linewidth = 1, label='35 clients (serviced 3/4th of all request)')


plt.xlabel('Time (s)')
plt.annotate('conflict=25%', xy = (0.6, 0.9), xycoords='axes fraction')
plt.annotate('rps=600', xy = (0.6, 0.8), xycoords='axes fraction')
# naming the y axis
plt.ylabel('CPU Usage (%)')

#plt.title('Aggregate CPU Usage of Five Servers with Different Amount of Load', y=-0.9)

  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.8));
# function to show the plot
plt.show()

# %%
#overall cpu usage at different conflict 15 client
import matplotlib.pyplot as plt
import numpy as np

 
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]


tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)

    
j=0
myfile = open("updated_rps\\ol_overall_cpu_usage_median_serverside_10_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y1.append(float(line))
            x1.append(j)
            if j%6==0:
                j=j+1
                y1.append(float(line))
                x1.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open("updated_rps\\ol_overall_cpu_usage_median_serverside_20_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y2.append(float(line))
            x2.append(j)
            if j%6==0:
                j=j+1
                y2.append(float(line))
                x2.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 



j=0
myfile = open("updated_rps\\ol_overall_cpu_usage_median_serverside_25_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y3.append(float(line))
            x3.append(j)
            if j%6==0:
                j=j+1
                y3.append(float(line))
                x3.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 


j=0
myfile = open("updated_rps\\ol_overall_cpu_usage_median_serverside_30_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y4.append(float(line))
            x4.append(j)
            if j%6==0:
                j=j+1
                y4.append(float(line))
                x4.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()


j=0
myfile = open("updated_rps\\ol_overall_cpu_usage_median_serverside_35_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y5.append(float(line))
            x5.append(j)
            if j%6==0:
                j=j+1
                y5.append(float(line))
                x5.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()



plt.ylim(0,2500)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)


plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='10 clients (serviced all request)') 
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='20 clients (serviced all request)')
plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='25 clients (serviced all request)')
plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='30 clients (serviced all request)')
plt.plot(x5, y5, color='orange', linestyle='solid', linewidth = 1, label='35 clients (serviced 3/4th of all request)')


plt.xlabel('Time (s)')
plt.annotate('conflict=25%', xy = (0.6, 0.9), xycoords='axes fraction')
plt.annotate('rps=600', xy = (0.6, 0.8), xycoords='axes fraction')
# naming the y axis
plt.ylabel('CPU Usage (%)')

#plt.title('Overall CPU Usage of Server Machine with Different Amount of Load', y=-0.9)

  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.8));
# function to show the plot
plt.show()
# function to show the plot
plt.show()

# %%
#per process cpu cost. different levels of consistency. 15 node
import matplotlib.pyplot as plt
import numpy as np

 
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]

tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)




a=[]

#a.append(0.0)

b=[]

#b.append(0.0)

c=[]

#c.append(0.0)


d=[]

#d.append(0.0)





#plt.plot(x, y, color='red', linestyle='solid', linewidth = 1)



j=0
myfile = open("updated_rps\ol_tput_10_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            tput_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  




j=0
myfile = open("updated_rps\\ol_overall_cpu_usage_median_serverside_10_clients.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            cpu_median[j]=float(line)
            if j%6==0:
                j=j+1
                cpu_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  



for j in range(0,1000):
   
    try: 
           
            y1.append(cpu_median[j]/tput_median[j])
           # y1.append(cpu_median[j])
           # y1.append(tput_median[j])
            x1.append(j)            
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        
             
        
j=0
myfile = open("updated_rps\ol_tput_20_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            tput_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open("updated_rps\\ol_overall_cpu_usage_median_serverside_20_clients.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            cpu_median[j]=float(line)
            if j%6==0:
                j=j+1
                cpu_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  



for j in range(0,1000):
   
    try: 
           
            y2.append(cpu_median[j]/tput_median[j])
            #y2.append(cpu_median[j])
            #y2.append(tput_median[j])
            x2.append(j)            
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")        
        
        
        
j=0
myfile = open("updated_rps\ol_tput_25_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            tput_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open("updated_rps\\ol_overall_cpu_usage_median_serverside_25_clients.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            cpu_median[j]=float(line)
            if j%6==0:
                j=j+1
                cpu_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  



for j in range(0,1000):
   
    try: 
           
            y3.append(cpu_median[j]/tput_median[j])
            #y3.append(cpu_median[j])
            #y3.append(tput_median[j])
            x3.append(j)            
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")        
              
myfile.close()  
            

j=0
myfile = open("updated_rps\ol_tput_30_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            tput_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open("updated_rps\\ol_overall_cpu_usage_median_serverside_30_clients.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            cpu_median[j]=float(line)
            if j%6==0:
                j=j+1
                cpu_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  



for j in range(0,1000):
   
    try: 
           
            y4.append(cpu_median[j]/tput_median[j])
            #y2.append(cpu_median[j])
            #y2.append(tput_median[j])
            x4.append(j)            
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")        

 



j=0
myfile = open("updated_rps\ol_tput_35_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            tput_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open("updated_rps\\ol_overall_cpu_usage_median_serverside_35_clients.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            cpu_median[j]=float(line)
            if j%6==0:
                j=j+1
                cpu_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  



for j in range(0,1000):
   
    try: 
           
            y5.append(cpu_median[j]/tput_median[j])
            #y2.append(cpu_median[j])
            #y2.append(tput_median[j])
            x5.append(j)            
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")        
       
        
        


plt.ylim(0,0.5)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)



plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='10 clients (serviced all request)') 
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='20 clients (serviced all request)')
plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='25 clients (serviced all request)')
plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='30 clients (serviced all request)')
plt.plot(x5, y5, color='orange', linestyle='solid', linewidth = 1, label='35 clients (serviced 3/4th of all request)')


plt.xlabel('Time (s)')
plt.annotate('conflict=25%', xy = (0.6, 0.9), xycoords='axes fraction')
plt.annotate('rps=600', xy = (0.6, 0.8), xycoords='axes fraction')
# naming the y axis
plt.ylabel('CPU Usage (%)/operation')

#plt.title('CPU Usage Cost of Each operation with Different Amount of Load', y=-0.9)

  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.8));
# function to show the plot
plt.show()
# function to show the plot
plt.show()
# Out:
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

 
#aggregate cpu usage of the client process at different conflict. 15 Clients  
    
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]

tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)


path="E:\\git repository\\copilot\\scripts\\updated_rps\\"

j=0
myfile = open(path+"ol_agg_cpu_usage_median_clientside_10_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y1.append(float(line))
            x1.append(j)
            j=j+1
            y1.append(float(line))
            x1.append(j)
            j=j+1
            y1.append(float(line))
            x1.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 



j=0
myfile = open(path+"ol_agg_cpu_usage_median_clientside_20_clients.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            y2.append(float(line))
            x2.append(j)
            j=j+1
            y2.append(float(line))
            x2.append(j)
            j=j+1
            y2.append(float(line))
            x2.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  

     
        
j=0
myfile = open(path+"ol_agg_cpu_usage_median_clientside_25_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y3.append(float(line))
            x3.append(j)
            j=j+1
            y3.append(float(line))
            x3.append(j)
            j=j+1
            y3.append(float(line))
            x3.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  
 
j=0
myfile = open(path+"ol_agg_cpu_usage_median_clientside_30_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y4.append(float(line))
            x4.append(j)
            j=j+1
            y4.append(float(line))
            x4.append(j)
            j=j+1
            y4.append(float(line))
            x4.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 


j=0
myfile = open(path+"ol_agg_cpu_usage_median_clientside_35_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y5.append(float(line))
            x5.append(j)
            j=j+1
            y5.append(float(line))
            x5.append(j)
            j=j+1
            y5.append(float(line))
            x5.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()
  


plt.ylim(0,5000)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)



plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='10 clients (received ack of all request)') 
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='20 clients (received ack of all request)')
plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='25 clients (received ack of all request)')
plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='30 clients (received ack of all request)')
plt.plot(x5, y5, color='orange', linestyle='solid', linewidth = 1, label='35 clients (received ack of 3/4th of all request)')

plt.xlabel('Time (s)')
plt.annotate('conflict=25%', xy = (0.6, 0.9), xycoords='axes fraction')
plt.annotate('rps=600', xy = (0.6, 0.8), xycoords='axes fraction')
# naming the y axis
plt.ylabel('CPU Usage (%)')

#plt.title('Aggregate CPU Usage of the Clients with Different Amount of Load', y=-0.9)

  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.8));
# function to show the plot
plt.show()
# function to show the plot
plt.show()

# %%
#overall cpu usage at different conflict 15 client in client machine
import matplotlib.pyplot as plt
import numpy as np

 
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]


tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)

    
j=0
myfile = open("updated_rps\\ol_overall_cpu_usage_median_clientside_10_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y1.append(float(line))
            x1.append(j)
            if j%6==0:
                j=j+1
                y1.append(float(line))
                x1.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open("updated_rps\\ol_overall_cpu_usage_median_clientside_20_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y2.append(float(line))
            x2.append(j)
            if j%6==0:
                j=j+1
                y2.append(float(line))
                x2.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 



j=0
myfile = open("updated_rps\\ol_overall_cpu_usage_median_clientside_25_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y3.append(float(line))
            x3.append(j)
            if j%6==0:
                j=j+1
                y3.append(float(line))
                x3.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 


j=0
myfile = open("updated_rps\\ol_overall_cpu_usage_median_clientside_30_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y4.append(float(line))
            x4.append(j)
            if j%6==0:
                j=j+1
                y4.append(float(line))
                x4.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()


j=0
myfile = open("updated_rps\\ol_overall_cpu_usage_median_clientside_35_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            y5.append(float(line))
            x5.append(j)
            if j%6==0:
                j=j+1
                y5.append(float(line))
                x5.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()


plt.ylim(0,4500)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)



plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='10 clients (received ack of all request)') 
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='20 clients (received ack of all request)')
plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='25 clients (received ack of all request)')
plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='30 clients (received ack of all request)')
plt.plot(x5, y5, color='orange', linestyle='solid', linewidth = 1, label='35 clients (received ack of 3/4th of all request)')


plt.xlabel('Time (s)')
plt.annotate('conflict=25%', xy = (0.95, 0.9), xycoords='axes fraction')
plt.annotate('rps=600', xy = (0.95, 0.8), xycoords='axes fraction')
# naming the y axis
plt.ylabel('CPU Usage (%)')

#plt.title('Overall CPU Usage of the Client Machine with Different Amount of Load', y=-0.9)

  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.8));
# function to show the plot
plt.show()
# function to show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

 
#aggregate netIO of the individual server process at different conflict. 15 Clients  
    
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]

tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)


path="E:\\git repository\\copilot\\scripts\\"

j=0
myfile = open(path+"updated_rps\\ol_agg_netIO_median_serverside_10_clients.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    
    try: 
            y1.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x1.append(j)
            j=j+1
            y1.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x1.append(j)
            j=j+1
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 



j=0
myfile = open(path+"updated_rps\\ol_agg_netIO_median_serverside_20_clients.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    
    try: 
            y2.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x2.append(j)
            j=j+1
            y2.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x2.append(j)
            j=j+1
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  

     
        
j=0
myfile = open(path+"updated_rps\\ol_agg_netIO_median_serverside_25_clients.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    
    try: 
            y3.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x3.append(j)
            j=j+1
            y3.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x3.append(j)
            j=j+1
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


 
j=0
myfile = open(path+"updated_rps\\ol_agg_netIO_median_serverside_30_clients.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    
    try: 
            y4.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x4.append(j)
            j=j+1
            y4.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x4.append(j)
            j=j+1
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()

j=0
myfile = open(path+"updated_rps\\ol_agg_netIO_median_serverside_35_clients.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    
    try: 
            y5.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x5.append(j)
            j=j+1
            y5.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x5.append(j)
            j=j+1
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()




  


plt.ylim(0,400)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)


plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='10 clients (serviced all request)') 
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='20 clients (serviced all request)')
plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='25 clients (serviced all request)')
plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='30 clients (serviced all request)')
plt.plot(x5, y5, color='orange', linestyle='solid', linewidth = 1, label='35 clients (serviced 3/4th of all request)')


plt.xlabel('Time (s)')
plt.annotate('conflict=25%', xy = (0.6, 0.9), xycoords='axes fraction')
plt.annotate('rps=600', xy = (0.6, 0.8), xycoords='axes fraction')
# naming the y axis
plt.ylabel('Network IO (Mbits/s)')

#plt.title('Aggregate Network IO of Five Servers with Different Amount of Load', y=-0.9)

  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.8));
# function to show the plot
plt.show()
# function to show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

 
#overall netIO of the individual server machine at different conflict. 15 Clients  
    
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]

tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)


path="E:\\git repository\\copilot\\scripts\\"

i=0
j=0
myfile = open(path+"updated_rps\\ol_overall_netIO_median_serverside_10_clients.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    i=i+1
    
    try: 
            if i>=30:
                y1.append((float(line1[0])+float(line1[0]))/(1024*1024))
                x1.append(j)
                j=j+1
         
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 



i=0
j=0
myfile = open(path+"updated_rps\\ol_overall_netIO_median_serverside_20_clients.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    i=i+1
    
    try: 
            if i>=30:
                y2.append((float(line1[0])+float(line1[0]))/(1024*1024))
                x2.append(j)
                j=j+1
         
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  

     
i=0      
j=0
myfile = open(path+"updated_rps\\ol_overall_netIO_median_serverside_25_clients.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    i=i+1
    try: 
            if i>=30: 
                y3.append((float(line1[0])+float(line1[0]))/(1024*1024))
                x3.append(j)
                j=j+1
      
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


i=0 
j=0
myfile = open(path+"updated_rps\\ol_overall_netIO_median_serverside_30_clients.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    i=i+1
    
    try:    
        if i>=30:
                y4.append((float(line1[0])+float(line1[0]))/(1024*1024))
                x4.append(j)
                j=j+1
      
    
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()

i=0
j=0
myfile = open(path+"updated_rps\\ol_overall_netIO_median_serverside_35_clients.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    i=i+1
    
    try: 
            if i>=30:
                y5.append((float(line1[0])+float(line1[0]))/(1024*1024))
                x5.append(j)
                j=j+1
     
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()




  


plt.ylim(0,1000)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)


plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='10 clients (serviced all request)') 
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='20 clients (serviced all request)')
plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='25 clients (serviced all request)')
plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='30 clients (serviced all request)')
plt.plot(x5, y5, color='orange', linestyle='solid', linewidth = 1, label='35 clients (serviced 3/4th of all request)')


plt.xlabel('Time (s)')
plt.annotate('conflict=25%', xy = (0.6, 0.9), xycoords='axes fraction')
plt.annotate('rps=600', xy = (0.6, 0.8), xycoords='axes fraction')
# naming the y axis
plt.ylabel('Network IO (Mbits/s)')

#plt.title('Overall Network IO of the Server Machine with Different Amount of Load', y=-0.9)

  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.8));
# function to show the plot
plt.show()
# function to show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

 
#aggregate netIO of the individual client process at different conflict. 15 Clients  
    
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]

tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)


path="E:\\git repository\\copilot\\scripts\\"

j=0
myfile = open(path+"updated_rps\\ol_agg_netIO_median_clientside_10_clients.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    
    try: 
            y1.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x1.append(j)
            j=j+1
            y1.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x1.append(j)
            j=j+1
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 



j=0
myfile = open(path+"updated_rps\\ol_agg_netIO_median_clientside_20_clients.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    
    try: 
            y2.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x2.append(j)
            j=j+1
            y2.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x2.append(j)
            j=j+1
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  

     
        
j=0
myfile = open(path+"updated_rps\\ol_agg_netIO_median_clientside_25_clients.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    
    try: 
            y3.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x3.append(j)
            j=j+1
            y3.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x3.append(j)
            j=j+1
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


 
j=0
myfile = open(path+"updated_rps\\ol_agg_netIO_median_clientside_30_clients.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    
    try: 
            y4.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x4.append(j)
            j=j+1
            y4.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x4.append(j)
            j=j+1
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()

j=0
myfile = open(path+"updated_rps\\ol_agg_netIO_median_clientside_35_clients.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    
    try: 
            y5.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x5.append(j)
            j=j+1
            y5.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x5.append(j)
            j=j+1
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()




  


plt.ylim(0,40)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)


plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='10 clients (serviced all request)') 
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='20 clients (serviced all request)')
plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='25 clients (serviced all request)')
plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='30 clients (serviced all request)')
plt.plot(x5, y5, color='orange', linestyle='solid', linewidth = 1, label='35 clients (serviced 3/4th of all request)')


plt.xlabel('Time (s)')
plt.annotate('conflict=25%', xy = (0.6, 0.9), xycoords='axes fraction')
plt.annotate('rps=600', xy = (0.6, 0.8), xycoords='axes fraction')
# naming the y axis
plt.ylabel('Network IO (Mbits/s)')

#plt.title('Aggregate Network IO of the Client Process with Different Amount of Load', y=-0.9)

  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.8));
# function to show the plot
plt.show()
# function to show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

 
#aggregate netIO of the client machine at different load 
    
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]

tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)


path="E:\\git repository\\copilot\\scripts\\"

i=0
j=0
myfile = open(path+"updated_rps\\ol_overall_netIO_median_clientside_10_clients.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    i=i+1
    
    try: 
            if i>=30:
                y1.append((float(line1[0])+float(line1[0]))/(1024*1024))
                x1.append(j)
                j=j+1
         
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 



i=0
j=0
myfile = open(path+"updated_rps\\ol_overall_netIO_median_clientside_20_clients.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    i=i+1
    
    try: 
            if i>=30:
                y2.append((float(line1[0])+float(line1[0]))/(1024*1024))
                x2.append(j)
                j=j+1
         
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  

     
i=0        
j=0
myfile = open(path+"updated_rps\\ol_overall_netIO_median_clientside_25_clients.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    i=i+1
    
    try: 
            if i>=30:
                y3.append((float(line1[0])+float(line1[0]))/(1024*1024))
                x3.append(j)
                j=j+1
      
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


i=0
j=0
myfile = open(path+"updated_rps\\ol_overall_netIO_median_clientside_30_clients.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    i=i+1
    
    try: 
            if i>=30: 
                y4.append((float(line1[0])+float(line1[0]))/(1024*1024))
                x4.append(j)
                j=j+1
      
    
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()

j=0
i=0
myfile = open(path+"updated_rps\\ol_overall_netIO_median_clientside_35_clients.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    i=i+1
    
    try: 
            if i>=30:
                y5.append((float(line1[0])+float(line1[0]))/(1024*1024))
                x5.append(j)
                j=j+1
     
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()




  


plt.ylim(0,1000)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)


plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='10 clients (recceived ack of all request)') 
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='20 clients (recceived ack of all request)')
plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='25 clients (recceived ack of all request)')
plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='30 clients (recceived ack of all request)')
plt.plot(x5, y5, color='orange', linestyle='solid', linewidth = 1, label='35 clients (recceived ack of 3/4th of all request)')


plt.xlabel('Time (s)')
plt.annotate('conflict=25%', xy = (0.6, 0.9), xycoords='axes fraction')
plt.annotate('rps=600', xy = (0.6, 0.8), xycoords='axes fraction')
# naming the y axis
plt.ylabel('Network IO (Mbits/s)')

#plt.title('Overall Network IO of the Client Machine with Different Amount of Load', y=-0.9)

  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.8));
# function to show the plot
plt.show()
# function to show the plot
plt.show()

# %%
#percentage amount of conflict for different level of level. 15 node
import matplotlib.pyplot as plt
import numpy as np

 
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]

tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)




a=[]

#a.append(0.0)

b=[]

#b.append(0.0)

c=[]

#c.append(0.0)


d=[]

#d.append(0.0)





#plt.plot(x, y, color='red', linestyle='solid', linewidth = 1)



j=0
myfile = open("updated_rps\ol_tput_10_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            tput_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  




j=0
myfile = open("updated_rps\\ol_conflict_10_clients.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            cpu_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  



for j in range(0,1000):
   
    try: 
           
            y1.append((cpu_median[j]/tput_median[j])*100)
           # y1.append(cpu_median[j])
           # y1.append(tput_median[j])
            x1.append(j)            
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        
             
        
j=0
myfile = open("updated_rps\ol_tput_20_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            tput_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open("updated_rps\\ol_conflict_20_clients.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            cpu_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  



for j in range(0,1000):
   
    try: 
           
            y2.append((cpu_median[j]/tput_median[j])*100)
            #y2.append(cpu_median[j])
            #y2.append(tput_median[j])
            x2.append(j)            
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")        
        
        
        
j=0
myfile = open("updated_rps\ol_tput_25_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            tput_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open("updated_rps\\ol_conflict_25_clients.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            cpu_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  



for j in range(0,1000):
   
    try: 
           
            y3.append((cpu_median[j]/tput_median[j])*100)
            #y3.append(cpu_median[j])
            #y3.append(tput_median[j])
            x3.append(j)            
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")        
              
myfile.close()  
            

j=0
myfile = open("updated_rps\ol_tput_30_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            tput_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open("updated_rps\\ol_conflict_30_clients.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            cpu_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  



for j in range(0,1000):
   
    try: 
           
            y4.append((cpu_median[j]/tput_median[j])*100)
            #y2.append(cpu_median[j])
            #y2.append(tput_median[j])
            x4.append(j)            
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")        

 



j=0
myfile = open("updated_rps\ol_tput_35_clients.txt")
for line in myfile:
    line.strip()
    
    try: 
            tput_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open("updated_rps\\ol_conflict_35_clients.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            cpu_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  



for j in range(0,1000):
   
    try: 
           
            y5.append((cpu_median[j]/tput_median[j])*100)
            #y2.append(cpu_median[j])
            #y2.append(tput_median[j])
            x5.append(j)            
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")        
       
        
        


plt.ylim(0,150)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)



plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='10 clients (serviced all request)') 
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='20 clients (serviced all request)')
plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='25 clients (serviced all request)')
plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='30 clients (serviced all request)')
plt.plot(x5, y5, color='orange', linestyle='solid', linewidth = 1, label='35 clients (serviced 3/4th of all request)')


plt.xlabel('Time (s)')
plt.annotate('conflict=25%', xy = (0.6, 0.9), xycoords='axes fraction')
plt.annotate('rps=600', xy = (0.6, 0.8), xycoords='axes fraction')
# naming the y axis
plt.ylabel('Amount of Conflict (%)')

#plt.title('Amount of Conflict of Five Servers with Different Amount of Load', y=-0.9)

  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.8));
# function to show the plot
plt.show()
# function to show the plot
plt.show()
# Out:
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

 
#aggregate cpu usage of the individual process at different conflict. 15 Clients  
    
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]

tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)


path="E:\\git repository\\copilot\\scripts\\"


j=0
myfile = open(path+"ol_cpu_usage_server_median_twenty_client.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            y2.append(float(line))
            x2.append(j)
            j=j+1
            y2.append(float(line))
            x2.append(j)
            j=j+1
            y2.append(float(line))
            x2.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  

 
 
j=0
myfile = open(path+"ol_cpu_usage_median_weak_conflict.txt")
for line in myfile:
    line.strip()
    
    try: 
            y4.append(float(line))
            x4.append(j)
            j=j+1
            y4.append(float(line))
            x4.append(j)
            j=j+1
            y4.append(float(line))
            x4.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 

  


plt.ylim(0,1500)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)



#plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='aggregate cpu usage(0% conflict)')
plt.plot(x2, y2, color='blue', linestyle='solid', linewidth = 1, label='aggregate cpu usage strong consistency (25% conflict)')
#plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='aggregate cpu usage (50% conflict )')
plt.plot(x4, y4, color='red', linestyle='solid', linewidth = 1, label='aggregate cpu usages weak consistency')

plt.xlabel('Time (s)')
# naming the y axis
plt.ylabel('CPU Usage (%)')

  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.75));
# function to show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#throughput at different conflict 15 client

i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]


tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)




a=[]

#a.append(0.0)

b=[]

#b.append(0.0)

c=[]

#c.append(0.0)

j=0
myfile = open("ol_tput_median_twenty_client.txt")
for line in myfile:
    line.strip()
    
    try: 
            y1.append(float(line))
            x1.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 


j=0
myfile = open("ol_tput_weak_consistency.txt")
for line in myfile:
    line.strip()
    
    try: 
            y2.append(float(line))
            x2.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()




plt.ylim(0,20000)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)



plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='strong consistency (25% conflict) (serviced all reqest)') 
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='weak consistency (25% conflict) (serviced all reqest)')
#plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='50% conflict (serviced all reqest)')
#plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='100% conflict (serviced all reqest)')

plt.xlabel('Time (s)')
# naming the y axis
plt.ylabel('Throughput')
  
# giving a title to my graph
#plt.title('Normalized CPU utilization of MultiPaxos and EPaxos')
  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.75));
# function to show the plot
plt.show()

# %%
#overall cpu usage at different conflict 15 client
import matplotlib.pyplot as plt
import numpy as np

 
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]


tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)

    
j=0
myfile = open("ol_overall_cpu_usage_server_twenty_client.txt")
for line in myfile:
    line.strip()
    
    try: 
            y1.append(float(line))
            x1.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open("ol_overall_cpu_usage_median_weak_consistency_server.txt")
for line in myfile:
    line.strip()
    
    try: 
            y2.append(float(line)-((20/100)*float(line)))
            x2.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 



 



plt.ylim(0,2500)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)



plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='strong consistency (25% conflict) (serviced all reqest)') 
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='weak consistency (25% conflict) (serviced all reqest)')


plt.xlabel('Time (s)')
# naming the y axis
plt.ylabel('Overall CPU Usage of Server (%)')
  
# giving a title to my graph
#plt.title('Normalized CPU utilization of MultiPaxos and EPaxos')
  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.75));
# function to show the plot
plt.show()

# %%
#overall cpu usage at different conflict 15 client in client machine
import matplotlib.pyplot as plt
import numpy as np

 
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]


tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)

    
j=0
myfile = open("ol_overall_cpu_usage_clientside_median_20_client.txt")
for line in myfile:
    line.strip()
    
    try: 
            y1.append(float(line))
            x1.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open("ol_overall_cpu_usage_median_weak_consistency_client.txt")
for line in myfile:
    line.strip()
    
    try: 
            y2.append(float(line))
            x2.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 








plt.ylim(0,3000)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)



plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='strong consistency (25% conflict) (serviced all reqest)') 
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='weak consistency (25% conflict) (serviced all reqest)')


plt.xlabel('Time (s)')
# naming the y axis
plt.ylabel('Overall CPU Usage of Client (%)')
  
# giving a title to my graph
#plt.title('Normalized CPU utilization of MultiPaxos and EPaxos')
  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.75));
# function to show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

 
#aggregate cpu usage of the client process at different conflict. 15 Clients  
    
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]

tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)


path="E:\\git repository\\copilot\\scripts\\"

j=0
myfile = open(path+"ol_agg_cpu_usage_clientside_20_client.txt")
for line in myfile:
    line.strip()
    
    try: 
            y1.append(float(line))
            x1.append(j)
            j=j+1
            y1.append(float(line))
            x1.append(j)
            j=j+1
            y1.append(float(line))
            x1.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 



j=0
myfile = open(path+"ol_cpu_usage_median_weak_consitency_client_agg.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            y2.append(float(line))
            x2.append(j)
            j=j+1
            y2.append(float(line))
            x2.append(j)
            j=j+1
            y2.append(float(line))
            x2.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  

     
        
 
 
 





plt.ylim(0,2500)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)



plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='Strong Consistency(25% conflict)')
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='Weak Consistency (25% conflict)')
#plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='aggregate cpu usage (50% conflict )')
#plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='aggregate cpu usages (100% conflict )')

plt.xlabel('Time (s)')
# naming the y axis
plt.ylabel('Aggregate CPU Usage of Client(%)')

  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.75));
# function to show the plot
plt.show()

# %%
#per process cpu cost. different levels of consistency. 15 node
import matplotlib.pyplot as plt
import numpy as np

 
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)




a=[]

#a.append(0.0)

b=[]

#b.append(0.0)

c=[]

#c.append(0.0)


d=[]

#d.append(0.0)





#plt.plot(x, y, color='red', linestyle='solid', linewidth = 1)



j=0
myfile = open("ol_tput_zero_conflict.txt")
for line in myfile:
    line.strip()
    
    try: 
            tput_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  




j=0
myfile = open("ol_tput_median_twenty_client.txt")
for line in myfile:
    line.strip()
    
    try: 
            tput_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open("ol_overall_cpu_usage_server_twenty_client.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            cpu_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  



for j in range(0,1000):
   
    try: 
           
            y1.append(cpu_median[j]/tput_median[j])
            #y2.append(cpu_median[j])
            #y2.append(tput_median[j])
            x1.append(j)            
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")        
        
        
        
             
        
j=0
myfile = open("ol_tput_weak_consistency.txt")
for line in myfile:
    line.strip()
    
    try: 
            tput_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open("ol_cpu_usage_median_weak_conflict.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            cpu_median[j]=float(line)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  



for j in range(0,1000):
   
    try: 
           
            y2.append(cpu_median[j]/tput_median[j])
            #y2.append(cpu_median[j])
            #y2.append(tput_median[j])
            x2.append(j)            
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")        
        
        
 






 
            


 



        
        


plt.ylim(0,1)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)



plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='Strong Consistency (25% conflict)') 
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='Weak Consistency (25% conflict)')
#plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='High Load (100 clients)')
#plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='High Load (100 clients)')
#plt.plot(c, b, color='red', linestyle='solid', linewidth = 1, label='MultiPaxos')





#plt.plot(x, b, color='blue', linestyle='solid', linewidth = 1, label='Follower (server1.2)')
  
#plt.plot(x, c, color='green', linestyle='solid', linewidth = 1, label='Follower (server1.3)')    

#plt.plot(x, d, color='brown', linestyle='solid', linewidth = 1, label='Follower (server1.4)')


#plt.plot(x, a, color='orange', linestyle='solid', linewidth = 1, label='Follower (server1.5)')
# naming the x axis
plt.xlabel('Time (s)')
# naming the y axis
plt.ylabel('CPU%/operations')
  
# giving a title to my graph
#plt.title('Normalized CPU utilization of MultiPaxos and EPaxos')
  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.75));
# function to show the plot
plt.show()
# Out:
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# ...
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'ZeroDivisionError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.
# Oops! <class 'IndexError'> occurred.
# Next entry.

# %%
import matplotlib.pyplot as plt
import numpy as np

 
#aggregate cpu usage of the individual process at different conflict. 15 Clients  
    
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]

tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)


path="E:\\git repository\\copilot\\scripts\\"

j=0
myfile = open(path+"ol_netIO_agg_server_median_twenty_client.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    
    try: 
            y1.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x1.append(j)
            j=j+1
            y1.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x1.append(j)
            j=j+1
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 



j=0
myfile = open(path+"ol_netIO_median_weak_consistency_serverprocess.txt")
for line in myfile:
    line.strip()
    line1=line.split(":")
    
    try: 
            y2.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x2.append(j)
            j=j+1
            y2.append((float(line1[0])+float(line1[0]))/(1024*1024))
            x2.append(j)
            j=j+1
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  

     
        
  


 





  


plt.ylim(0,150)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)



plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='Strong Consistency (25% conflict)')
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='Weak Consistency (25% conflict)')


plt.xlabel('Time (s)')
# naming the y axis
plt.ylabel('Network IO (MB)')

  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.8));
# function to show the plot
plt.show()

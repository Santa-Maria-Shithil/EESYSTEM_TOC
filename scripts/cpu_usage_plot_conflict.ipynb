# %%
import matplotlib.pyplot as plt
import numpy as np

 
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]

tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)




a=[]

#a.append(0.0)

b=[]

#b.append(0.0)

c=[]

#c.append(0.0)


d=[]

#d.append(0.0)





#plt.plot(x, y, color='red', linestyle='solid', linewidth = 1)

path="E:\\git repository\\copilot\\scripts\\"

j=0
myfile = open(path+"ol_cpu_usage_median_zero_conflict.txt")
for line in myfile:
    line.strip()
    
    try: 
            y1.append(float(line))
            x1.append(j)
            j=j+1
            y1.append(float(line))
            x1.append(j)
            j=j+1
            y1.append(float(line))
            x1.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 

print(y1)


j=0
myfile = open(path+"ol_cpu_usage_median_twentyfive_conflict.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            y2.append(float(line))
            x2.append(j)
            j=j+1
            y2.append(float(line))
            x2.append(j)
            j=j+1
            y2.append(float(line))
            x2.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  

     
        
j=0
myfile = open(path+"ol_cpu_usage_median_fifty_conflict.txt")
for line in myfile:
    line.strip()
    
    try: 
            y3.append(float(line))
            x3.append(j)
            j=j+1
            y3.append(float(line))
            x3.append(j)
            j=j+1
            y3.append(float(line))
            x3.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  
 
j=0
myfile = open(path+"ol_cpu_usage_median_hundred_conflict.txt")
for line in myfile:
    line.strip()
    
    try: 
            y4.append(float(line))
            x4.append(j)
            j=j+1
            y4.append(float(line))
            x4.append(j)
            j=j+1
            y4.append(float(line))
            x4.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 


j=0
myfile = open(path+"ol_overall_cpu_usage_median_zero_conflict.txt")
for line in myfile:
    line.strip()
    
    try: 
            y5.append(float(line))
            x5.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()
  


plt.ylim(0,1500)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)



plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='0% conflict aggregate cpu usage(serviced all reqest)')
plt.plot(x5, y5, color='blue', linestyle='dashed', linewidth = 1, label='0% conflict overall cpu usage(serviced all reqest)')
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='25% conflict (serviced all reqest)')
plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='50% conflict (serviced all reqest)')
plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='100% conflict (serviced all reqest)')
#plt.plot(c, b, color='red', linestyle='solid', linewidth = 1, label='MultiPaxos')





#plt.plot(x, b, color='blue', linestyle='solid', linewidth = 1, label='Follower (server1.2)')
  
#plt.plot(x, c, color='green', linestyle='solid', linewidth = 1, label='Follower (server1.3)')    

#plt.plot(x, d, color='brown', linestyle='solid', linewidth = 1, label='Follower (server1.4)')


#plt.plot(x, a, color='orange', linestyle='solid', linewidth = 1, label='Follower (server1.5)')
# naming the x axis
plt.xlabel('Time (s)')
# naming the y axis
plt.ylabel('Throughput')
  
# giving a title to my graph
#plt.title('Normalized CPU utilization of MultiPaxos and EPaxos')
  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.75));
# function to show the plot
plt.show()
# Out:
# [546.6600000000001, 546.6600000000001, 546.6600000000001, 557.6, 557.6, 557.6, 562.2099999999999, 562.2099999999999, 562.2099999999999, 548.54, 548.54, 548.54, 547.62, 547.62, 547.62, 547.76, 547.76, 547.76, 542.76, 542.76, 542.76, 546.98, 546.98, 546.98, 919.72, 919.72, 919.72, 928.21, 928.21, 928.21, 926.27, 926.27, 926.27, 926.9, 926.9, 926.9, 922.4000000000001, 922.4000000000001, 922.4000000000001, 927.91, 927.91, 927.91, 926.2800000000001, 926.2800000000001, 926.2800000000001, 926.4900000000001, 926.4900000000001, 926.4900000000001, 923.88, 923.88, 923.88, 926.8699999999999, 926.8699999999999, 926.8699999999999, 929.99, 929.99, 929.99, 927.8800000000001, 927.8800000000001, 927.8800000000001, 928.9000000000001, 928.9000000000001, 928.9000000000001, 942.4699999999999, 942.4699999999999, 942.4699999999999, 924.48, 924.48, 924.48, 926.92, 926.92, 926.92, 927.3100000000002, 927.3100000000002, 927.3100000000002, 926.3900000000001, 926.3900000000001, 926.3900000000001, 928.28, 928.28, 
# ...

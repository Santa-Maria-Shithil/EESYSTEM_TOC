# %%
import matplotlib.pyplot as plt
import numpy as np

 
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]

tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)




a=[]

#a.append(0.0)

b=[]

#b.append(0.0)

c=[]

#c.append(0.0)


d=[]

#d.append(0.0)





#plt.plot(x, y, color='red', linestyle='solid', linewidth = 1)

path="E:\\git repository\\copilot\\scripts"

j=0
myfile = open(path+"\\tput_median_zconflict.txt")
for line in myfile:
    line.strip()
    
    try: 
            tput_median[j]=float(line)
            j=j+1
            if j==100:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open(path+"\\cpu_usage_median_zconflict.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            cpu_median[j]=float(line)
            j=j+1
            if j==100:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  



for j in range(0,1000):
   
    try: 
           
            #y1.append(cpu_median[j]/tput_median[j])
            #y1.append(cpu_median[j])
            y1.append(tput_median[j])
            x1.append(j)            
            if j==100:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        
        
print(y1)      
        
j=0
myfile = open(path+"\\tput_median_tfconflict.txt")
for line in myfile:
    line.strip()
    
    try: 
            tput_median[j]=float(line)
            j=j+1
            if j==100:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open(path+"\\cpu_usage_median_tfconflict.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            cpu_median[j]=float(line)
            j=j+1
            if j==100:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  



for j in range(0,1000):
   
    try: 
           
            #y2.append(cpu_median[j]/tput_median[j])
            #y2.append(cpu_median[j])
            y2.append(tput_median[j])
            x2.append(j)            
            if j==100:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")        
        
        
        
j=0
myfile = open(path+"\\tput_median_fconflict.txt")
for line in myfile:
    line.strip()
    
    try: 
            tput_median[j]=float(line)
            j=j+1
            if j==100:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open(path+"\\cpu_usage_median_fconflict.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            cpu_median[j]=float(line)
            j=j+1
            if j==100:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  



for j in range(0,1000):
   
    try: 
           
            #y3.append(cpu_median[j]/tput_median[j])
            #y3.append(cpu_median[j])
            y3.append(tput_median[j])
            x3.append(j)            
            if j==100:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")        

        
j=0
myfile = open(path+"\\tput_median_hconflict.txt")
for line in myfile:
    line.strip()
    
    try: 
            tput_median[j]=float(line)
            j=j+1
            if j==100:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open(path+"\\cpu_usage_median_hconflict.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            cpu_median[j]=float(line)
            j=j+1
            if j==100:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  



for j in range(0,1000):
   
    try: 
           
            #y4.append(cpu_median[j]/tput_median[j])
            #y4.append(cpu_median[j])
            y4.append(tput_median[j])
            x4.append(j)            
            if j==100:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")        
              
        
           
        
print(y4)  


plt.ylim(0,50000)
plt.xlim(20,70)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)



plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='0% conflict (30 clients)') 
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='25% conflict (30 clients)')
plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='50% conflict (30 clients)')
plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='100% conflict (30 clients)')
#plt.plot(c, b, color='red', linestyle='solid', linewidth = 1, label='MultiPaxos')





#plt.plot(x, b, color='blue', linestyle='solid', linewidth = 1, label='Follower (server1.2)')
  
#plt.plot(x, c, color='green', linestyle='solid', linewidth = 1, label='Follower (server1.3)')    

#plt.plot(x, d, color='brown', linestyle='solid', linewidth = 1, label='Follower (server1.4)')


#plt.plot(x, a, color='orange', linestyle='solid', linewidth = 1, label='Follower (server1.5)')
# naming the x axis
plt.xlabel('Time (s)')
# naming the y axis
plt.ylabel('Throughput')
  
# giving a title to my graph
#plt.title('Normalized CPU utilization of MultiPaxos and EPaxos')
  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.75));
# function to show the plot
plt.show()
# Out:
# [29.0, 18720.0, 21558.4, 21188.6, 21021.4, 21443.8, 21339.0, 22149.8, 22241.2, 20844.4, 21358.2, 21091.2, 21239.0, 21708.8, 21194.8, 21735.2, 21411.6, 21798.6, 20234.4, 21983.6, 21006.0, 20857.2, 21844.6, 22674.2, 23565.2, 23216.8, 22014.0, 22218.8, 22220.8, 22426.8, 21197.4, 21947.4, 22592.0, 21580.0, 23153.2, 22047.4, 22562.6, 21413.4, 20753.4, 21275.8, 21439.2, 21375.8, 21519.8, 21911.6, 21229.8, 22262.8, 22212.0, 21750.4, 20491.8, 21178.4, 21230.6, 21833.2, 21948.8, 21017.4, 21641.0, 21848.6, 22518.8, 22641.8, 22074.4, 22183.2, 20858.6, 21774.2, 22183.8, 22254.6, 21657.0, 22921.4, 21814.0, 22605.2, 23561.4, 22731.8, 21918.8, 21296.4, 21887.4, 21397.6, 21636.6, 21879.0, 22399.8, 21524.8, 20531.6, 21308.8, 21561.4, 22193.6, 20217.8, 20500.0, 21877.2, 21922.6, 21084.8, 21808.0, 21206.4, 22198.8, 22443.8, 21461.4, 20492.0, 21133.8, 18902.4, 20859.6, 20811.4, 21548.4, 21539.4, 20306.8, 0.0]
# ...

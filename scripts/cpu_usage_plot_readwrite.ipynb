# %%
import matplotlib.pyplot as plt
import numpy as np

 
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]

tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)




a=[]

#a.append(0.0)

b=[]

#b.append(0.0)

c=[]

#c.append(0.0)


d=[]

#d.append(0.0)





#plt.plot(x, y, color='red', linestyle='solid', linewidth = 1)

path="E:\\git repository\\copilot\\scripts"

j=0
myfile = open(path+"\\tput_median_zreadhwrite.txt")
for line in myfile:
    line.strip()
    
    try: 
            tput_median[j]=float(line)
            j=j+1
            if j==100:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open(path+"\\cpu_usage_median_zreadhwrite.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            cpu_median[j]=float(line)
            j=j+1
            if j==100:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  



for j in range(0,1000):
   
    try: 
           
            #y1.append(cpu_median[j]/tput_median[j])
            #y1.append(cpu_median[j])
            y1.append(tput_median[j])
            x1.append(j)            
            if j==100:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        
        
print(y1)      
        
j=0
myfile = open(path+"\\tput_median_freadfwrite.txt")
for line in myfile:
    line.strip()
    
    try: 
            tput_median[j]=float(line)
            j=j+1
            if j==100:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open(path+"\\cpu_usage_median_freadfwrite.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            cpu_median[j]=float(line)
            j=j+1
            if j==100:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  



for j in range(0,1000):
   
    try: 
           
            #y2.append(cpu_median[j]/tput_median[j])
            #y2.append(cpu_median[j])
            y2.append(tput_median[j])
            x2.append(j)            
            if j==100:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")        
        
        
        


plt.ylim(0,50000)
plt.xlim(20,70)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)



plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='0% read 100% write (100 clients)') 
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='50% read 50% write (100 clients)')
#plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='50% conflict (30 clients)')
#plt.plot(c, b, color='red', linestyle='solid', linewidth = 1, label='MultiPaxos')





#plt.plot(x, b, color='blue', linestyle='solid', linewidth = 1, label='Follower (server1.2)')
  
#plt.plot(x, c, color='green', linestyle='solid', linewidth = 1, label='Follower (server1.3)')    

#plt.plot(x, d, color='brown', linestyle='solid', linewidth = 1, label='Follower (server1.4)')


#plt.plot(x, a, color='orange', linestyle='solid', linewidth = 1, label='Follower (server1.5)')
# naming the x axis
plt.xlabel('Time (s)')
# naming the y axis
plt.ylabel('Throughput')
  
# giving a title to my graph
#plt.title('Normalized CPU utilization of MultiPaxos and EPaxos')
  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.75));
# function to show the plot
plt.show()
# Out:
# [99.0, 23369.2, 35410.0, 36988.0, 37440.8, 35965.2, 37249.2, 37245.2, 36727.4, 34894.4, 36326.4, 36653.8, 36917.6, 36871.6, 37800.6, 37405.0, 37557.8, 36368.0, 38213.2, 37197.8, 36559.8, 35909.0, 37011.4, 36780.8, 37707.2, 37842.6, 37755.2, 36844.4, 38045.4, 37109.2, 36459.8, 35206.6, 34293.8, 35654.0, 37201.8, 37589.8, 37285.8, 37054.8, 37366.8, 36758.0, 36357.4, 36502.4, 36620.8, 36957.0, 36993.6, 37399.6, 37125.8, 37307.4, 36985.0, 37805.6, 37098.4, 37425.2, 37121.6, 37173.6, 36505.4, 37327.8, 35571.4, 36078.6, 37034.0, 37611.2, 37662.0, 36330.4, 35521.8, 36490.4, 36455.0, 37441.2, 35894.4, 37407.2, 37307.8, 37632.2, 37717.4, 37005.2, 37006.8, 37512.4, 37150.2, 37307.2, 34008.4, 34965.4, 35235.8, 36443.0, 36588.0, 37351.0, 37109.8, 36840.2, 36945.4, 37584.2, 37960.4, 37808.6, 38165.8, 37077.0, 37023.8, 38147.6, 38131.2, 37341.2, 37551.2, 37599.8, 36760.0, 37283.8, 37539.4, 36866.4, 0.0]

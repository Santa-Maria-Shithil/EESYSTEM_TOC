# %%
import matplotlib.pyplot as plt
import numpy as np

 
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]


tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)




a=[]

#a.append(0.0)

b=[]

#b.append(0.0)

c=[]

#c.append(0.0)


d=[]

#d.append(0.0)





#plt.plot(x, y, color='red', linestyle='solid', linewidth = 1)



j=0
myfile = open("tput_median_ten_client.txt")
for line in myfile:
    line.strip()
    
    try: 
            y1.append(float(line))
            x1.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open("tput_median_twenty_client.txt")
for line in myfile:
    line.strip()
    
    try: 
            y2.append(float(line))
            x2.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 



j=0
myfile = open("tput_median_twentyfive_client.txt")
for line in myfile:
    line.strip()
    
    try: 
            y3.append(float(line))
            x3.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 


j=0
myfile = open("tput_median_thirty_client.txt")
for line in myfile:
    line.strip()
    
    try: 
            y4.append(float(line))
            x4.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()


print(y1)
        
        
      
              
        
           
        
        


plt.ylim(0,100000)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)



plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='10 clients') 
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='20 clients')
plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='25 clients')
plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='30 clients')
#plt.plot(c, b, color='red', linestyle='solid', linewidth = 1, label='MultiPaxos')





#plt.plot(x, b, color='blue', linestyle='solid', linewidth = 1, label='Follower (server1.2)')
  
#plt.plot(x, c, color='green', linestyle='solid', linewidth = 1, label='Follower (server1.3)')    

#plt.plot(x, d, color='brown', linestyle='solid', linewidth = 1, label='Follower (server1.4)')


#plt.plot(x, a, color='orange', linestyle='solid', linewidth = 1, label='Follower (server1.5)')
# naming the x axis
plt.xlabel('Time (s)')
# naming the y axis
plt.ylabel('Throughput')
  
# giving a title to my graph
#plt.title('Normalized CPU utilization of MultiPaxos and EPaxos')
  
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0
# %%
import matplotlib.pyplot as plt
import numpy as np

 
#aggregate cpu usage of the individual process at different conflict. 15 Clients  
    
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]

tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)


path="E:\\git repository\\copilot\\scripts\\"

j=0
myfile = open(path+"different_interval\\ol_agg_cpu_usage_median_serverside_1_us.txt")
for line in myfile:
    line.strip()
    
    try: 
            y1.append(float(line))
            x1.append(j)
            j=j+1
            y1.append(float(line))
            x1.append(j)
            j=j+1
            y1.append(float(line))
            x1.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 



j=0
myfile = open(path+"different_interval\\ol_agg_cpu_usage_median_serverside_1_ms.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            y2.append(float(line))
            x2.append(j)
            j=j+1
            y2.append(float(line))
            x2.append(j)
            j=j+1
            y2.append(float(line))
            x2.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  

     
        
j=0
myfile = open(path+"different_interval\\ol_agg_cpu_usage_median_serverside_50_ms.txt")
for line in myfile:
    line.strip()
    
    try: 
            y3.append(float(line))
            x3.append(j)
            j=j+1
            y3.append(float(line))
            x3.append(j)
            j=j+1
            y3.append(float(line))
            x3.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  
 
j=0
myfile = open(path+"different_interval\\ol_agg_cpu_usage_median_serverside_100_ms.txt")
for line in myfile:
    line.strip()
    
    try: 
            y4.append(float(line))
            x4.append(j)
            j=j+1
            y4.append(float(line))
            x4.append(j)
            j=j+1
            y4.append(float(line))
            x4.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 


j=0
myfile = open(path+"different_interval\\ol_agg_cpu_usage_median_serverside_100_ms.txt")
for line in myfile:
    line.strip()
    
    try: 
            y5.append(float(line))
            x5.append(j)
            j=j+1
            y5.append(float(line))
            x5.append(j)
            j=j+1
            y5.append(float(line))
            x5.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()

  


plt.ylim(0,1500)
plt.xlim(0,600)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)



plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='1us interval')
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='1ms interval')
plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='50ms interval')
plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='100ms interval')

plt.annotate('No of Clients=20', xy = (0.6, 0.9), xycoords='axes fraction')
plt.annotate('rps=600', xy = (0.6, 0.8), xycoords='axes fraction')

plt.xlabel('Time (s)')
# naming the y axis
plt.ylabel('CPU Usage (%)')

#plt.title('Aggregate CPU Usage of Five Servers with Different Amount of Conflicts', y=-0.9)
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.8));
# function to show the plot
plt.show()

# %%
#overall cpu usage at different conflict 15 client
import matplotlib.pyplot as plt
import numpy as np

 
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]


tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)

    
j=0
myfile = open(".\\different_interval\\ol_overall_cpu_usage_median_serverside_1_us.txt")
for line in myfile:
    line.strip()
    
    try: 
            y1.append(float(line))
            x1.append(j)
            j=j+1
            if j==600:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open(".\\different_interval\\ol_overall_cpu_usage_median_serverside_1_ms.txt")
for line in myfile:
    line.strip()
    
    try: 
            y2.append(float(line))
            x2.append(j)
            j=j+1
            if j==600:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 



j=0
myfile = open(".\\different_interval\\ol_overall_cpu_usage_median_serverside_50_ms.txt")
for line in myfile:
    line.strip()
    
    try: 
            y3.append(float(line))
            x3.append(j)
            j=j+1
            if j==600:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 


j=0
myfile = open(".\\different_interval\\ol_overall_cpu_usage_median_serverside_100_ms.txt")
for line in myfile:
    line.strip()
    
    try: 
            y4.append(float(line))
            x4.append(j)
            j=j+1
            if j==600:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()

j=0
myfile = open("ol_overall_cpu_usage_server_zero_conflict_rps.txt")
for line in myfile:
    line.strip()
    
    try: 
            y5.append(float(line))
            x5.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()



plt.ylim(0,2500)
plt.xlim(0,600)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)




plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='1us interval')
#plt.plot(x5, y5, color='orange', linestyle='solid', linewidth = 1, label='0% conflict')
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='1ms interval')
plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='50ms interval')
plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='100ms interval')

plt.annotate('No of Clients=20', xy = (0.6, 0.9), xycoords='axes fraction')
plt.annotate('rps=600', xy = (0.6, 0.8), xycoords='axes fraction')


plt.xlabel('Time (s)')
plt.ylabel('CPU Usage (%)')

#plt.title('Overall CPU Usage of Server Machine with Different Amount of Conflict', y=-0.9)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.8));
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#throughput at different conflict 15 client

i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]


tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)




a=[]

#a.append(0.0)

b=[]

#b.append(0.0)

c=[]

#c.append(0.0)


d=[]

j=0
myfile = open(".\\different_interval\\ol_tput_median_1_us.txt")
for line in myfile:
    line.strip()
    
    try: 
            y1.append(float(line))
            x1.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  


j=0
myfile = open(".\\different_interval\\ol_tput_median_1_ms.txt")
for line in myfile:
    line.strip()
    
    try: 
            y2.append(float(line))
            x2.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 



j=0
myfile = open(".\\different_interval\\ol_tput_median_50_ms.txt")
for line in myfile:
    line.strip()
    
    try: 
            y3.append(float(line))
            x3.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 


j=0
myfile = open(".\\different_interval\\ol_tput_median_100_ms.txt")
for line in myfile:
    line.strip()
    
    try: 
            y4.append(float(line))
            x4.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()

plt.ylim(0,15000)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)




plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='1us interval')
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='1ms interval')
plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='50ms interval')
plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='100ms interval')

plt.xlabel('Time (s)')
plt.ylabel('Throughput (ops/s)')
plt.annotate('No of Clients=20', xy = (0.6, 0.9), xycoords='axes fraction')
plt.annotate('rps=600', xy = (0.6, 0.8), xycoords='axes fraction')
# naming the y axis
#plt.title('Throughput with Different Amount of Conflicts', y=-0.9)
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.8));
# function to show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

 
#aggregate cpu usage of the client process at different conflict. 15 Clients  
    
i=1
j=2
maxi=0
maxj=0
x1=[]
y1=[]

x2=[]
y2=[]

x3=[]
y3=[]

x4=[]
y4=[]

x5=[]
y5=[]

tput_median=[]
cpu_median=[]

for i in range(0,701):
    tput_median.append(0.0)
    
for i in range(0,701):
    cpu_median.append(0.0)


path="E:\\git repository\\copilot\\scripts\\"

j=0
myfile = open(path+"ol_cpu_usage_median_zero_conflict_client.txt")
for line in myfile:
    line.strip()
    
    try: 
            y1.append(float(line))
            x1.append(j)
            j=j+1
            y1.append(float(line))
            x1.append(j)
            j=j+1
            y1.append(float(line))
            x1.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 



j=0
myfile = open(path+"ol_cpu_usage_median_twentyfive_conflict_client.txt")
for line in myfile:
    line.strip()
 
    
    try: 
            y2.append(float(line))
            x2.append(j)
            j=j+1
            y2.append(float(line))
            x2.append(j)
            j=j+1
            y2.append(float(line))
            x2.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  

     
        
j=0
myfile = open(path+"ol_cpu_usage_median_fifty_conflict_client.txt")
for line in myfile:
    line.strip()
    
    try: 
            y3.append(float(line))
            x3.append(j)
            j=j+1
            y3.append(float(line))
            x3.append(j)
            j=j+1
            y3.append(float(line))
            x3.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()  
 
j=0
myfile = open(path+"ol_cpu_usage_median_hundred_conflict_client.txt")
for line in myfile:
    line.strip()
    
    try: 
            y4.append(float(line))
            x4.append(j)
            j=j+1
            y4.append(float(line))
            x4.append(j)
            j=j+1
            y4.append(float(line))
            x4.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close() 


j=0
myfile = open(path+"ol_agg_cpu_usage_client_zero_conflict_rps.txt")
for line in myfile:
    line.strip()
    
    try: 
            y5.append(float(line))
            x5.append(j)
            j=j+1
            y5.append(float(line))
            x5.append(j)
            j=j+1
            y5.append(float(line))
            x5.append(j)
            j=j+1
            if j==500:
                break
      
    except Exception as e:
        print("Oops!", e.__class__, "occurred.")
        print("Next entry.")
        print()
   
# plotting the points 
myfile.close()
  


plt.ylim(0,2500)
plt.xlim(20,500)

SMALL_SIZE = 15
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)

plt.plot(x1, y1, color='blue', linestyle='solid', linewidth = 1, label='0% conflict')
#plt.plot(x5, y5, color='orange', linestyle='solid', linewidth = 1, label='0% conflict')
plt.plot(x2, y2, color='red', linestyle='solid', linewidth = 1, label='25% conflict')
plt.plot(x3, y3, color='green', linestyle='solid', linewidth = 1, label='50% conflict')
plt.plot(x4, y4, color='gray', linestyle='solid', linewidth = 1, label='100% conflict')


plt.xlabel('Time (s)')
plt.ylabel('CPU Usage (%)')
plt.annotate('No of Clients=15', xy = (0.6, 0.9), xycoords='axes fraction')
plt.annotate('rps=1000', xy = (0.6, 0.8), xycoords='axes fraction')

plt.title('Aggregate CPU Usage of Client Machine with Different Amount of Conflict', y=-0.9)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.8));
# function to show the plot
plt.show()
